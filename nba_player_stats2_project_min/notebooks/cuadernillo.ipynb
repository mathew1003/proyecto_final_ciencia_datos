# %% [markdown]
# # NBA Player Stats 2 — Predicción de PTS

# %%
import pandas as pd
from pathlib import Path
base_dir = Path('.').resolve().parent
df = pd.read_csv(base_dir / 'data' / 'NBA_Player_Stats_2.csv')
df.head()
