# %% [markdown]
# # 02 · Limpieza

# %%
clean_path = r"C:\Users\User\OneDrive\Documentos\nba_project\nba_project\data\processed\clean.csv"
df = pd.read_csv(clean_path)
df.head()
# Out:
#        Player   Season   Tm Pos  Age    MP   FGA  3PA    FT%    3P%    2P%  \
# 0  Player_082  2013-14  LAL  PG   27  27.0  16.6  9.6  0.747  0.334  0.611
# 1  Player_032  2008-09  CHI  SG   27  24.8  12.1  4.9  0.579  0.229  0.461
# 2  Player_087  2018-19  GSW   C   22  18.1  19.9  6.4  0.777  0.250  0.462
# 3  Player_005  2011-12  GSW  PG   27  23.8  12.8  3.0  0.950  0.349  0.426
# 4  Player_030  2005-06  WAS   C   26  14.3   8.7  3.5  0.844  0.362  0.492
#
#    FTA    FG%   PTS       era
# 0  5.7  0.450  21.4    2010s+
# 1  2.2  0.368  11.8  pre-2010
# 2  4.4  0.394  17.9    2010s+
# 3  5.8  0.408  14.4    2010s+
# 4  3.6  0.439   8.3  pre-2010
