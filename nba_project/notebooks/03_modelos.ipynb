# %% [markdown]
# # 03 · Modelos

# %%
# 03 · Modelos
from src.train_model import main as train

train(k_top=8, ask_input=False)

from pathlib import Path
import json, pandas as pd

# Subir un nivel porque el notebook está en /notebooks/
ROOT = Path('..').resolve()

metrics_path = ROOT / 'reports' / 'metrics.json'
print(metrics_path.read_text())

import IPython.display as I

I.display(pd.read_csv(ROOT / 'reports' / 'feature_ranking.csv').head(20))

from IPython.display import Image, display

display(Image(filename=str(ROOT / 'reports' / 'figuras' / 'y_vs_pred.png')))
display(Image(filename=str(ROOT / 'reports' / 'figuras' / 'residuals.png')))
# Out:
# Métricas: {'RMSE': 2.760663335513029, 'MAE': 2.068347851886895, 'R2': 0.7361713507743699}
# {
#   "overall": {
#     "RMSE": 2.760663335513029,
#     "MAE": 2.068347851886895,
#     "R2": 0.7361713507743699
#   }
# }
#   feature  abs_corr
# 0     FGA  0.819216
# 1     3PA  0.385053
# 2     3P%  0.231694
# 3     2P%  0.167736
# 4      MP  0.108463
# 5     Age  0.044107
# 6     FT%  0.042386
